# %%
import yfinance as yf
import numpy as np
import seaborn as sns
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
N_20 =  ['HDFCBANK.NS', 'RELIANCE.NS', 'ICICIBANK.NS', 'INFY.NS', 'ITC.NS', 'TCS.NS', 'LT.NS', 'AXISBANK.NS', 'KOTAKBANK.NS','HINDUNILVR.NS', 'SBIN.NS', 'BHARTIARTL.NS', 'BAJFINANCE.NS', 'ASIANPAINT.NS','MARUTI.NS', 'HCLTECH.NS', 'SUNPHARMA.NS', 'TITAN.NS', 'LTIM.NS', 'ADANIENT.NS']
data = yf.download(N_20, start='2022-01-01', end='2023-11-06')['Adj Close']
# Out:
# [*********************100%%**********************]  20 of 20 completed

# %%
corr = data.corr()
print(corr)
# Out:
#                ADANIENT.NS  ASIANPAINT.NS  AXISBANK.NS  BAJFINANCE.NS  \
# ADANIENT.NS       1.000000       0.310198     0.243580       0.178863
# ASIANPAINT.NS     0.310198       1.000000     0.261052       0.807278
# AXISBANK.NS       0.243580       0.261052     1.000000       0.441265
# BAJFINANCE.NS     0.178863       0.807278     0.441265       1.000000
# BHARTIARTL.NS     0.307236       0.358224     0.914089       0.571930
# HCLTECH.NS       -0.282765       0.139553     0.674585       0.447977
# HDFCBANK.NS       0.124124       0.178702     0.807534       0.218488
# HINDUNILVR.NS     0.488956       0.353011     0.636529       0.225040
# ICICIBANK.NS      0.391709       0.446924     0.882837       0.499779
# INFY.NS          -0.108836       0.058342    -0.322836       0.193929
# ITC.NS            0.108940       0.188964     0.830638       0.280688
# KOTAKBANK.NS      0.338364       0.508420     0.133957       0.327011
# ...

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
top = corr.unstack().sort_values(ascending=True).drop_duplicates().head(5).index.tolist()
top
# Out:
# [('ITC.NS', 'INFY.NS'),
#  ('HINDUNILVR.NS', 'INFY.NS'),
#  ('ICICIBANK.NS', 'INFY.NS'),
#  ('ADANIENT.NS', 'TCS.NS'),
#  ('MARUTI.NS', 'INFY.NS')]

# %%
l = []
for i in range(0,4):
    for j in top[i]:
        if j not in l:
            l.append(j)
print("Best stock to choose for portfolio optimisation are:")
for stocks in l:
    print(stocks)
# Out:
# Best stock to choose for portfolio optimisation are:
# ITC.NS
# INFY.NS
# HINDUNILVR.NS
# ICICIBANK.NS
# ADANIENT.NS
# TCS.NS
